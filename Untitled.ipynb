# %%
# !pip install livef1 --no-deps

# %%
import logging

# %%
from data_loader import load_session
r = load_session("2026", "Australian Grand Prix", "Practice 1")
print(r["telemetry"].columns.tolist())
# Out:
#   [cache HIT]  2026__Australian_Grand_Prix__Practice_1
# ['session', 'season', 'meeting', 'session_name']

# %%
# !python app.py

# %%
# !git lfs track "*.csv"  # or whatever file type
# !git lfs track "*.h5"
# !git lfs track "*.parquet"

# %%
# !python fetch_historical_results.py
# Out:
# 12:51:29  INFO      Seasons to process: [2021, 2022, 2024, 2025, 2026]
# 12:51:29  INFO      Output directory  : C:\Users\sophi\F1\data\historical_results
# 12:51:29  INFO      Force reload      : False
# 12:51:29  INFO      ==================================================================
# 12:51:29  INFO      Season 2021
# 12:51:29  INFO      ==================================================================
# 12:51:29  INFO        22 rounds found
# 12:51:29  INFO        Round  1  Bahrain Grand Prix
# 12:51:31  INFO          [R] cache hit – 20 rows
# 12:51:31  INFO          [Q] cache hit – 20 rows
# 12:51:31  INFO        Round  2  Emilia Romagna Grand Prix
# 12:51:31  INFO          [R] cache hit – 20 rows
# 12:51:31  INFO          [Q] cache hit – 20 rows
# 12:51:31  INFO        Round  3  Portuguese Grand Prix
# 12:51:31  INFO          [R] cache hit – 20 rows
# 12:51:31  INFO          [Q] cache hit – 20 rows
# 12:51:31  INFO        Round  4  Spanish Grand Prix
# ...
